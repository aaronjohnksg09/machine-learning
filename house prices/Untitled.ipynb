# %%
# !pip install kagglehub
# Out:
# Collecting kagglehub
#   Downloading kagglehub-1.0.2-py3-none-any.whl.metadata (40 kB)
# Collecting kagglesdk<1.0,>=0.1.22 (from kagglehub)
#   Downloading kagglesdk-0.1.37-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: packaging in c:\users\dell\anaconda3\lib\site-packages (from kagglehub) (25.0)
# Requirement already satisfied: pyyaml in c:\users\dell\anaconda3\lib\site-packages (from kagglehub) (6.0.3)
# Requirement already satisfied: requests in c:\users\dell\anaconda3\lib\site-packages (from kagglehub) (2.32.5)
# Requirement already satisfied: tqdm in c:\users\dell\anaconda3\lib\site-packages (from kagglehub) (4.67.1)
# Requirement already satisfied: protobuf in c:\users\dell\anaconda3\lib\site-packages (from kagglesdk<1.0,>=0.1.22->kagglehub) (5.29.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\dell\anaconda3\lib\site-packages (from requests->kagglehub) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\anaconda3\lib\site-packages (from requests->kagglehub) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dell\anaconda3\lib\site-packages (from requests->kagglehub) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\anaconda3\lib\site-packages (from requests->kagglehub) (2025.11.12)
# Requirement already satisfied: colorama in c:\users\dell\anaconda3\lib\site-packages (from tqdm->kagglehub) (0.4.6)
# Downloading kagglehub-1.0.2-py3-none-any.whl (70 kB)
# Downloading kagglesdk-0.1.37-py3-none-any.whl (262 kB)
# Installing collected packages: kagglesdk, kagglehub
#
#    ---------------------------------------- 0/2 [kagglesdk]
#    ---------------------------------------- 0/2 [kagglesdk]
#    ---------------------------------------- 0/2 [kagglesdk]
#    ---------------------------------------- 0/2 [kagglesdk]
#    ---------------------------------------- 0/2 [kagglesdk]
#    ---------------------------------------- 0/2 [kagglesdk]
#    -------------------- ------------------- 1/2 [kagglehub]
#    ---------------------------------------- 2/2 [kagglehub]
#
# Successfully installed kagglehub-1.0.2 kagglesdk-0.1.37

# %%
import kagglehub

path = kagglehub.competition_download(
    'house-prices-advanced-regression-techniques',
    output_dir=r'C:\Users\DELL\Desktop\Machine learning\house prices'
)

print("Dataset saved at:", path)
# Out:
# ---------------------------------------------------------------------------
# UnauthenticatedError                      Traceback (most recent call last)
# Cell In[3], line 3
#       1 import kagglehub
# ----> 3 path = kagglehub.competition_download(
#       4     'house-prices-advanced-regression-techniques',
#       5     output_dir=r'C:\Users\DELL\Desktop\Machine learning\house prices'
#       6 )
#       8 print("Dataset saved at:", path)
#
# File ~\anaconda3\Lib\site-packages\kagglehub\competition.py:30, in competition_download(handle, path, force_download, output_dir)
#      28 h = parse_competition_handle(handle)
#      29 logger.info(f"Downloading competition: {h.to_url()} ...", extra={**EXTRA_CONSOLE_BLOCK})
# ---> 30 path, _ = registry.competition_resolver(
#      31     h,
#      32     path,
#      33     force_download=force_download,
#      34     output_dir=output_dir,
#      35 )
#      36 return path
#
# File ~\anaconda3\Lib\site-packages\kagglehub\registry.py:28, in MultiImplRegistry.__call__(self, *args, **kwargs)
#      26 for impl in reversed(self._impls):
#      27     if impl.is_supported(*args, **kwargs):
# ---> 28         return impl(*args, **kwargs)
#      29     else:
#      30         fails.append(type(impl).__name__)
#
# File ~\anaconda3\Lib\site-packages\kagglehub\resolver.py:35, in Resolver.__call__(self, handle, path, force_download, output_dir)
#      15 def __call__(
#      16     self,
#      17     handle: T,
#    (...)     21     output_dir: str | None = None,
#      22 ) -> tuple[str, int | None]:
#      23     """Resolves a handle into a path with the requested file(s) and the resource's version number.
#      24
#      25     Args:
#    (...)     33         Some cases where version number might be missing: Competition datasource, API-based models.
#      34     """
# ---> 35     path, version = self._resolve(
#      36         handle,
#      37         path,
#      38         force_download=force_download,
#      39         output_dir=output_dir,
#      40     )
#      42     # Note handles are immutable, so _resolve() could not have altered our reference
#      43     register_datasource_access(handle, version)
#
# File ~\anaconda3\Lib\site-packages\kagglehub\http_resolver.py:55, in CompetitionHttpResolver._resolve(self, h, path, force_download, output_dir)
#      53     if cached_path:
#      54         return cached_path, None
# ---> 55     raise UnauthenticatedError()
#      57 out_path = cache.get_path(h, path)
#      59 if output_dir:
#
# UnauthenticatedError: User is not authenticated

# %%
import kagglehub

# Download latest version
path = kagglehub.competition_download('house-prices-advanced-regression-techniques')

print("Path to competition files:", path)
# Out:
# ---------------------------------------------------------------------------
# UnauthenticatedError                      Traceback (most recent call last)
# Cell In[4], line 4
#       1 import kagglehub
#       3 # Download latest version
# ----> 4 path = kagglehub.competition_download('house-prices-advanced-regression-techniques')
#       6 print("Path to competition files:", path)
#
# File ~\anaconda3\Lib\site-packages\kagglehub\competition.py:30, in competition_download(handle, path, force_download, output_dir)
#      28 h = parse_competition_handle(handle)
#      29 logger.info(f"Downloading competition: {h.to_url()} ...", extra={**EXTRA_CONSOLE_BLOCK})
# ---> 30 path, _ = registry.competition_resolver(
#      31     h,
#      32     path,
#      33     force_download=force_download,
#      34     output_dir=output_dir,
#      35 )
#      36 return path
#
# File ~\anaconda3\Lib\site-packages\kagglehub\registry.py:28, in MultiImplRegistry.__call__(self, *args, **kwargs)
#      26 for impl in reversed(self._impls):
#      27     if impl.is_supported(*args, **kwargs):
# ---> 28         return impl(*args, **kwargs)
#      29     else:
#      30         fails.append(type(impl).__name__)
#
# File ~\anaconda3\Lib\site-packages\kagglehub\resolver.py:35, in Resolver.__call__(self, handle, path, force_download, output_dir)
#      15 def __call__(
#      16     self,
#      17     handle: T,
#    (...)     21     output_dir: str | None = None,
#      22 ) -> tuple[str, int | None]:
#      23     """Resolves a handle into a path with the requested file(s) and the resource's version number.
#      24
#      25     Args:
#    (...)     33         Some cases where version number might be missing: Competition datasource, API-based models.
#      34     """
# ---> 35     path, version = self._resolve(
#      36         handle,
#      37         path,
#      38         force_download=force_download,
#      39         output_dir=output_dir,
#      40     )
#      42     # Note handles are immutable, so _resolve() could not have altered our reference
#      43     register_datasource_access(handle, version)
#
# File ~\anaconda3\Lib\site-packages\kagglehub\http_resolver.py:55, in CompetitionHttpResolver._resolve(self, h, path, force_download, output_dir)
#      53     if cached_path:
#      54         return cached_path, None
# ---> 55     raise UnauthenticatedError()
#      57 out_path = cache.get_path(h, path)
#      59 if output_dir:
#
# UnauthenticatedError: User is not authenticated
